# %% [markdown]
# # ***Deep Learning with Python***
#
# **Author(s)**: Francois Chollet
#
# **Published**: 2021 (2nd Edition)
#
# ## ***Table of Contents***
#
# ***Chapter 1: What is Deep Learning?***
# - `1.1`: ***Artificial Intelligence, Machine Learning, and Deep Learning***
# - `1.2`: ***Before Deep Learning: A Brief History of Machine Learning***
# - `1.3`: ***Why Deep Learning? Why Now?***
#
# ***Chapter 2: The Mathematical Building Blocks of Neural Networks***
# - `2.1`: ***A First Look at a Neural Network***
# - `2.2`: ***Data Representations for Neural Networks***
# - `2.3`: ***The Gears of Neural Networks: Tensor Operations***
# - `2.4`: ***The Engine of Neural Networks: Gradient-Based Optimization***
# - `2.5`: ***Example***
#
# ***Chapter 3: Introduction to Keras and TensorFlow***
# - `3.1`: ***TensorFlow***
# - `3.2`: ***Keras***
# - `3.3`: ***History of Keras and TensorFlow***
# - `3.4`: ***Setting up a Deep Learning Workspace***
# - `3.5`: ***First Steps with TensorFlow***
# - `3.6`: ***Keras API: Anatomy of a Neural Network***
#
# ***Chapter 4: Getting Started: Classification and Regression***
# - `4.1`: ***Classifying Movie Reviews (Classification)***
# - `4.2`: ***Classifying Newswires (Multiclass Classification)***
# - `4.3`: ***Predicting Housing Prices (Regression)***
#
# ***Chapter 5: Fundamentals of Machine Learning***
# - `5.1`: ***Generalization: The Goal of ML***
# - `5.2`: ***Evaluating ML Models***
# - `5.3`: ***Improving Model Fit***
# - `5.4`: ***Improving Generalization***
#
# ***Chapter 6: The Universal Workflow of Machine Learning***
# - `6.1`: ***Define the Task***
# - `6.2`: ***Develop a Model***
# - `6.3`: ***Deploy the Model***
#
# ***Chapter 7: Working with Keras: A Deep Dive***
# - `7.1`: ***A Spectrum of Workflows***
# - `7.2`: ***Different Ways to Build Keras Models***
# - `7.3`: ***Using Built-In Training and Evaluation Loops***
# - `7.4`: ***Writing Your Own Training and Evaluation Loops***
#
# ***Chapter 8: Introduction to Deep Learning for Computer Vision***
# - `8.1`: ***Introduction to convnets***
# - `8.2`: ***Training a convnet From Scratch on a Small Dataset***
# - `8.3`: ***Leveraging a Pre-Trained Model***
#
# ***Chapter 9: Advanced Deep Learning for Computer Vision***
# - `9.1`: ***Three Essential Computer Vision Tasks***
# - `9.2`: ***An Image Segmentation Example***
# - `9.3`: ***Modern Convnet Architecture Patterns***
# - `9.4`: ***Interpreting What convnets Learn***
#
# ***Chapter 10: Deep Learning for Timeseries***
# - `10.1`: ***Different Kind of Timeseries Tasks***
# - `10.2`: ***A Temperature-Forecasting Example***
# - `10.3`: ***Understanding Recurrent Neural Networks***
# - `10.4`: ***Advanced Use of Recurrent Neural Networks***
#
# ***Chapter 11: Deep Learning for Text***
# - `11.1`: ***NLP: Overview***
# - `11.2`: ***Preparing Text Data***
# - `11.3`: ***Two Approaches for Representing Groups of Words: Set and Sequences***
# - `11.4`: ***Transformers + Architecture***
# - `11.5`: ***Sequence-to-Sequence Learning***
#
# ***Chapter 12: Generative Deep Learning***
# - `12.1`: ***Text Generation***
# - `12.2`: ***DeepDream***
# - `12.3`: ***Neural Style Transfer***
# - `12.4`: ***Generating Images with Variational Autoencoders***
# - `12.5`: ***Generative Adversarial Networks (GANs)***
#
#
# ***Chapter 13: Best Practices for the Real World***
# - `13.1`: ***Getting the Most Out of Your Models***
# - `13.2`: ***Scaling-up Model Training***
#
# ***Chapter 14: Conclusions***
# - `14.1`: ***Key Concepts in Review***
# - `14.2`: ***Limitations***
# - `14.3`: ***Greater Generality in AI***
# - `14.4`: ***Implementing Intelligence: Missing Ingredients***
# - `14.5`: ***The Future of Deep Learning***
# - `14.6`: ***Staying up to Date***
